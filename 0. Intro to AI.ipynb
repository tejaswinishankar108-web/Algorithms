# %% [markdown]
# ### Intro to AI with Python

# %% [markdown]
# #### Traditional AI techniques:

# %% [raw]
# 1. Search
# 2. Knowledge: through logical reasoning, knowledge base agents
#     Not(~)/OR(inverted ^)/And(^)/Implication(->)/Bidirectional<->)
# 3. Uncertainty: through probability; will it rain or not
# 4. Optimization
# 5. Learning: Machine Learning
# 6. Neural Networks: ANNs; through deep learning
# 7. Language: NLP, for machine to understand human langauge

# %% [markdown]
# #### 1. Search

# %% [raw]
# Example: Navigation; logistics;
# Maps suggest the best possible route using algorithms:Optimization
# Delivery charges based on distance, availability of agents
# Search problems:
# 1. Agent: entitiy that learn the environment and acts upon tha environment; Example: Driver in a car
# 2. State: Configuration of the agent and its environment; Eg: different places on the route that we would encounter while travel
# 3. Initial State: The state in which the agent begins; Eg: Source
# 4. Actions: Choices that can be executed in a particular state Eg: The directions we chose
# 5. Transition model: ----
# 6. State space: All the possible states which is reachable from source
# 7. Goal test/ Destination test: Ways to determin whether a given state is a goal state
# 8. Path cost: Numerical cost associated with a given path
# ----
# 9. Optimal solution
# 10. Node: Data structure that keeps track of : state/parent(node that generated this node)/action/path cost
# 11. Approach:
# Depth First Search
# - May not deliver solution if takes wrong route
# Breadth first search: Search that always expands the shallowest node in the frontier
# + Guarantees the solution
# Uninformed Search: No specific knowledge
# Informed search: uses problem specific knowledge to find the solutions more efficiently
# -> Greedy Best-First Search: Heuristic decisions
# - Won't know where is the dead end

# %%
s=Stack()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 s=Stack()
#
# NameError: name 'Stack' is not defined

# %%
from collections import deque

# Initialize the queue
queue = deque()

# Enqueue: Add elements to the back
queue.append("Task 1")
queue.append("Task 2")
queue.append("Task 3")
print("Queue state:", list(queue))
# Out:
# Queue state: ['Task 1', 'Task 2', 'Task 3']

# %%
from collections import deque

graph = {
    "A": ["B", "C"],
    "B": ["D", "E"],
    "C": ["F"],
    "D": [],
    "E": [],
    "F": []
}

queue = deque(["A"])
visited = []

while queue:
    node = queue.popleft()

    if node not in visited:
        visited.append(node)

        for neighbour in graph[node]:
            queue.append(neighbour)

print(visited)
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F']

# %%
graph = {
    "A": ["B", "C"],
    "B": ["D", "E"],
    "C": ["F"],
    "D": [],
    "E": [],
    "F": []
}

stack = ["A"]
visited = []

while stack:
    node = stack.pop()

    if node not in visited:
        visited.append(node)

        for neighbour in reversed(graph[node]):
            stack.append(neighbour)

print(visited)
# Out:
# ['A', 'B', 'D', 'E', 'C', 'F']
